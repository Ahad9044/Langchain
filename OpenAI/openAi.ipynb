# %%
from dotenv import load_dotenv

load_dotenv()

# %%
# Calling OpenAI API 

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o")

response = llm.invoke("What are the principles of MARK ZUKERBERG")
print(response.content)
# Out:
# Mark Zuckerberg, the co-founder and CEO of Facebook (now Meta Platforms, Inc.), is known for several guiding principles and philosophies throughout his leadership. While he hasn't explicitly outlined a formal list of principles like some other tech leaders, key themes and principles often associated with him include:
#
# 1. **Move Fast and Break Things**: This was an early motto for Facebook, emphasizing the importance of speed and innovation, even at the risk of making mistakes. The idea is to prioritize rapid development and iteration.
#
# 2. **Be Bold**: Taking risks is encouraged to drive innovation. Zuckerberg has often emphasized the importance of boldness and not being afraid to pursue ambitious goals.
#
# 3. **Focus on Impact**: Efforts should be directed towards projects and initiatives that have the potential to make the most significant impact.
#
# 4. **Build Social Value**: Zuckerberg has expressed a commitment to connecting people and building communities, aiming to ensure that his work contributes positively to society.
#
# 5. **Creating a More Open and Connected World**: This has been a core mission of Facebook—fostering more openness and connectivity between people worldwide.
#
# 6. **Long-Term Vision**: Zuckerberg emphasizes the importance of focusing on long-term goals rather than short-term financial concerns. This includes investments in future technologies like virtual reality and the metaverse.
#
# 7. **Continuous Learning and Improvement**: Zuckerberg is known for being a self-learner and encourages a culture of learning and curiosity within his company.
#
# 8. **Promoting Transparency**: Although this has been a contentious area, Zuckerberg has often spoken about the need for transparency in communication and decision-making.
#
# It's important to note that while these principles have guided Zuckerberg's leadership style and decisions at Meta, they have also evolved over time, especially in response to various challenges and controversies the company has faced.

# %%
# import os
# from dotenv import load_dotenv
# load_dotenv()

# os.environ['OPENAI_API_KEY'] =os.getenv("OPENAI_API_KEY")


# os.environ['LANGCHAIN_API_KEY'] =os.getenv("LANGCHAIN_API_KEY")
# os.environ["LANGCHAIN_TRACKING_V2"] ="true"
# os.environ['LANGSMITH_PROJECT'] =os.getenv("LANGSMITH_PROJECT")

# %%
# from langchain_openai import ChatOpenAI

# llm = ChatOpenAI(model="gpt-4o")

# response = llm.invoke("DIFFERENCE BETWEEN ISLAM , CHRISTIANALITY AND JEWS")
# print(response.content)
# Out:
# Islam, Christianity, and Judaism are three of the world's major monotheistic religions, meaning they worship a single, all-powerful God. Despite their common roots in the Abrahamic tradition and some shared beliefs, they have distinct differences in their doctrines, practices, scriptures, and historical developments. Here are some key differences:
#
# ### Founding and Key Figures:
# - **Judaism** is the oldest of the three, founded around the 2nd millennium BCE. Key figures include Abraham, Moses, and the prophets. Moses is particularly significant as he is regarded as the lawgiver who recieved the Torah from God.
#
# - **Christianity** emerged in the 1st century CE, rooted in the teachings of Jesus of Nazareth, who Christians believe is the Son of God and the savior of humanity. His crucifixion and resurrection are central tenets of Christian faith.
#
# - **Islam** was founded in the 7th century CE by the Prophet Muhammad, who is considered the last prophet in a long line that includes figures like Abraham, Moses, and Jesus. Muslims believe the Quran was revealed to Muhammad by Allah (God).
#
# ### Scriptures:
# - **Judaism** primarily relies on the Hebrew Bible, particularly the Torah, which comprises the first five books. It also includes other texts like the Talmud, which is a key interpretative text.
#
# - **Christianity** uses the Bible, which consists of the Old Testament (largely similar to the Hebrew Bible) and the New Testament, detailing the teachings and life of Jesus Christ.
#
# - **Islam**'s holy scripture is the Quran, believed to be the literal word of God as revealed to Muhammad. Supplementary texts include the Hadith, which are sayings and actions of Muhammad.
#
# ### Beliefs:
# - **God**: All three religions are monotheistic, but their understanding of God varies. Christians believe in the Trinity (Father, Son, Holy Spirit), which is not accepted by Judaism and Islam.
#
# - **Jesus**: In Christianity, Jesus is the central figure, seen as the Son of God and the savior. Judaism considers Jesus a historical figure but not the Messiah or divine. In Islam, Jesus (Isa) is a prophet and messenger but not divine, and he was not crucified in Islamic belief.
#
# - **Salvation**: Christianity emphasizes faith in Jesus Christ for salvation. Judaism focuses on living a righteous life according to the law and traditions for favor in God's eyes. Islam teaches that salvation is a combination of faith in Allah, good deeds, and following the Five Pillars of Islam.
#
# ### Religious Practices:
# - **Judaism** involves practices such as observing the Sabbath, dietary laws (Kashrut), and festivals like Passover and Yom Kippur.
#
# - **Christianity**'s practices include rites like baptism and communion. Worship generally takes place in churches, with Sunday as the primary day of worship.
#
# - **Islam** follows the Five Pillars: Shahada (faith), Salat (prayer), Zakat (charity), Sawm (fasting, especially during Ramadan), and Hajj (pilgrimage to Mecca). Worship is conducted in mosques, with Friday as the special day of congregation.
#
# ### Afterlife:
# - **Judaism** has varied beliefs about the afterlife, with less focus on it compared to this life. Concepts such as Sheol, resurrection, and Olam Ha-Ba ('the world to come') might be considered.
#
# - **Christianity** emphasizes the afterlife with beliefs in heaven and hell and eternal life through Jesus' resurrection.
#
# - **Islam** also has a definitive belief in the afterlife, with Jannah (paradise) and Jahannam (hell) representing the ultimate destinations based on one's deeds and faith.
#
# These differences create distinct religious landscapes, even though they share some common historical origins and ethical teachings. Each religion is rich in its traditions, cultures, and interpretations, contributing to the complex tapestry of global faith practices.
