# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gpt-4.1",
    model_provider="openai"
)

print(model.invoke("what's love? ").content)

# %% [markdown]
# Integration of Tools

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gpt-4.1",
    model_provider="openai"
)

# %%
from langchain.tools import tool

@tool
def get_weather(location: str)-> str : 
    """ get the weather at the location"""
    return f"It's sunny in {location}"

model_with_tools= model.bind_tools([get_weather])

# %%
for tool_call in response.tool_calls:
    print(f"Tool : {tool_call['name']}")
    print(f"Args : {tool_call['args']}")
# Out:
# Tool : get_weather
# Args : {'location': 'lucknow'}

# %%
response = model_with_tools.invoke("What's the weather in lucknow")
print(response)
for tool_call in response.tool_calls:
    print(f"Tool : {tool_call['name']}")
    print(f"Args : {tool_call['args']}")
# Out:
# content='' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 50, 'total_tokens': 65, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4.1-2025-04-14', 'system_fingerprint': 'fp_c2b7d6d912', 'id': 'chatcmpl-DbkySir9uuKPKO7krv5h8fu1CYyOn', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None} id='lc_run--019df290-e633-7270-b1f1-3cb762c2d85e-0' tool_calls=[{'name': 'get_weather', 'args': {'location': 'lucknow'}, 'id': 'call_8awO7JGvSzYQNPN6zwimzC8i', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 50, 'output_tokens': 15, 'total_tokens': 65, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# Tool : get_weather
# Args : {'location': 'lucknow'}

# %%
tool_result = get_weather.invoke(tool_call["args"])
tool_result
# Out:
# "It's sunny in lucknow"
